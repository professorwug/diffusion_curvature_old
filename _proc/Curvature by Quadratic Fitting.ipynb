# %% [raw]
# ---
# description: Based off of Hickock's 2023 method, but using diffusion-based volume
#   estimation.
# output-file: curvature by quadratic fitting.html
# title: Scalar Curvature by Volume Comparison
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->
