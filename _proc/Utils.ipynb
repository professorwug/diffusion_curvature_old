# %% [raw]
# ---
# description: Handy snippets for graph learning, some specific to diffusion curvature,
#   some more general purpose.
# output-file: utils.html
# title: Utils
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# Most are self explanatory. A small description is appended to those that aren't.

# %%
#| echo: false
#| output: asis
show_doc(kronecker_delta)
# Out:
# ---
#
# [source](https://github.com/professorwug/diffusion_curvature/blob/main/diffusion_curvature/utils.py#L8){target="_blank" style="float:right; font-size:smaller"}
#
# ### kronecker_delta
#
# >      kronecker_delta (length, idx=None)
#
# returns np array of len with all zeroes except idx.
#
# |    | **Type** | **Default** | **Details** |
# | -- | -------- | ----------- | ----------- |
# | length |  |  | length of array. If you pass an array or list, length is set to size of the first dimension. |
# | idx | NoneType | None | idx to make nonzero. If none, fills a random idx. |

# %%
#| echo: false
#| output: asis
show_doc(plot_3d)
# Out:
# ---
#
# [source](https://github.com/professorwug/diffusion_curvature/blob/main/diffusion_curvature/utils.py#L28){target="_blank" style="float:right; font-size:smaller"}
#
# ### plot_3d
#
# >      plot_3d (X, distribution=None, title='', lim=None, use_plotly=False,
# >               zlim=None, colorbar=False, cmap='plasma')
