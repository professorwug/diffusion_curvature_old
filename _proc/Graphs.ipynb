# %% [raw]
# ---
# output-file: graphs.html
# title: Graph Creation Utils
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(get_umap_graph)
# Out:
# ---
#
# [source](https://github.com/professorwug/diffusion_curvature/blob/main/diffusion_curvature/graphs.py#L103){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_umap_graph
#
# >      get_umap_graph (X, knn=5, **kwargs)
#
# |    | **Type** | **Default** | **Details** |
# | -- | -------- | ----------- | ----------- |
# | X |  |  |  |
# | knn | int | 5 | knn default to 15 in UMAP |
# | kwargs |  |  |  |

# %%
#| echo: false
#| output: asis
show_doc(get_scanpy_graph)
# Out:
# ---
#
# [source](https://github.com/professorwug/diffusion_curvature/blob/main/diffusion_curvature/graphs.py#L92){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_scanpy_graph
#
# >      get_scanpy_graph (X, knn=5, **kwargs)

# %%
#| echo: false
#| output: asis
show_doc(get_alpha_decay_graph)
# Out:
# ---
#
# [source](https://github.com/professorwug/diffusion_curvature/blob/main/diffusion_curvature/graphs.py#L73){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_alpha_decay_graph
#
# >      get_alpha_decay_graph (X, knn:int=5, decay:float=40.0,
# >                             anisotropy:float=0, n_pca:int=None, **kwargs)

# %%
#| echo: false
#| output: asis
show_doc(get_knn_graph)
# Out:
# ---
#
# [source](https://github.com/professorwug/diffusion_curvature/blob/main/diffusion_curvature/graphs.py#L69){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_knn_graph
#
# >      get_knn_graph (X, knn=5, **kwargs)

# %%
#| echo: false
#| output: asis
show_doc(diff_aff)
# Out:
# ---
#
# [source](https://github.com/professorwug/diffusion_curvature/blob/main/diffusion_curvature/graphs.py#L43){target="_blank" style="float:right; font-size:smaller"}
#
# ### diff_aff
#
# >      diff_aff (graph)
#
# Compute the diffusion affinity for a pygsp graph.

# %%
#| echo: false
#| output: asis
show_doc(kernel_degree)
# Out:
# ---
#
# [source](https://github.com/professorwug/diffusion_curvature/blob/main/diffusion_curvature/graphs.py#L34){target="_blank" style="float:right; font-size:smaller"}
#
# ### kernel_degree
#
# >      kernel_degree (graph)
#
# Compute the kernel degree for a pygsp graph.

# %%
#| echo: false
#| output: asis
show_doc(diff_op)
# Out:
# ---
#
# [source](https://github.com/professorwug/diffusion_curvature/blob/main/diffusion_curvature/graphs.py#L24){target="_blank" style="float:right; font-size:smaller"}
#
# ### diff_op
#
# >      diff_op (graph)
#
# Compute the diffusion operator for a pygsp graph.
